# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv(r"C:\Users\saksh\Downloads\Dry_Bean_Dataset.csv")
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
num= df.columns[:-1]
num
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4'],
#       dtype='object')

# %%
for i in num:
    fig,ax=plt.subplots(1,2,figsize=(10,12))
    ax[0].hist(df[i])
    ax[1].boxplot(df[i])
    plt.suptitle(i)
    plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,12))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df.drop(['MajorAxisLength','MinorAxisLength','Perimeter'],axis=1,inplace= True)

# %%
num= list(num)
num.remove('MajorAxisLength')
num.remove('MinorAxisLength')
num.remove('Perimeter')

# %%
import seaborn as sns
plt.figure(figsize=(10,12))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df.drop(['ConvexArea','EquivDiameter','ShapeFactor1'],axis=1,inplace= True)
num.remove('ConvexArea')
num.remove('EquivDiameter')
num.remove('ShapeFactor1')

# %%
import seaborn as sns
plt.figure(figsize=(10,12))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df.drop('AspectRation',axis=1,inplace= True)
num.remove('AspectRation')

# %%
import seaborn as sns
plt.figure(figsize=(10,12))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df.drop(['roundness','Compactness','ShapeFactor2'],axis=1,inplace= True)
num.remove('roundness')
num.remove('Compactness')
num.remove('ShapeFactor2')

# %%
import seaborn as sns
plt.figure(figsize=(10,12))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df.drop('Eccentricity',axis=1,inplace= True)
num.remove('Eccentricity')
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df[num].corr(),annot= True)
plt.show()

# %%
df['Class'].value_counts()
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Class']= le.fit_transform(df['Class'])
df
# Out:
#         Area    Extent  Solidity  ShapeFactor3  ShapeFactor4  Class
# 0      28395  0.763923  0.988856      0.834222      0.998724      5
# 1      28734  0.783968  0.984986      0.909851      0.998430      5
# 2      29380  0.778113  0.989559      0.825871      0.999066      5
# 3      30008  0.782681  0.976696      0.861794      0.994199      5
# 4      30140  0.773098  0.990893      0.941900      0.999166      5
# ...      ...       ...       ...           ...           ...    ...
# 13606  42097  0.714574  0.990331      0.642988      0.998385      3
# 13607  42101  0.799943  0.990752      0.676099      0.998219      3
# 13608  42139  0.729932  0.989899      0.676884      0.996767      3
# 13609  42147  0.705389  0.987813      0.668237      0.995222      3
# 13610  42159  0.788962  0.989648      0.616221      0.998180      3
#
# [13611 rows x 6 columns]

# %%
x= df.drop('Class',axis=1)
y= df['Class']

# %%
x= x.values
y=y.values

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size= 0.2, random_state= 100)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree= DecisionTreeClassifier(criterion= 'gini', max_depth=10, min_samples_leaf=1, min_samples_split=2)
dtree.fit(x_train,y_train)
y_train_predicted= dtree.predict(x_train)
y_test_predicted= dtree.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,classification_report

# %%
print('Model Performance')
print('Training Accuracy: ',accuracy_score(y_train,y_train_predicted))
print(confusion_matrix(y_train,y_train_predicted))
print(classification_report(y_train,y_train_predicted))

print('-----------------------------------------------------------------')

print('Model Performance')
print('Testing Accuracy: ',accuracy_score(y_test,y_test_predicted))
print(confusion_matrix(y_test,y_test_predicted))
print(classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy:  0.9468221895664952
# [[ 972    0   68    0    1    4   28]
#  [   0  413    0    0    0    0    0]
#  [  40    0 1295    0    6    3    7]
#  [   0    0    0 2685    1    7  129]
#  [   3    0   14    6 1496    0   27]
#  [   3    0    0   17    0 1554   29]
#  [   3    0   12  145    8   18 1894]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      1073
#            1       1.00      1.00      1.00       413
#            2       0.93      0.96      0.95      1351
#            3       0.94      0.95      0.95      2822
#            4       0.99      0.97      0.98      1546
#            5       0.98      0.97      0.97      1603
#            6       0.90      0.91      0.90      2080
#
#     accuracy                           0.95     10888
#    macro avg       0.96      0.95      0.95     10888
# weighted avg       0.95      0.95      0.95     10888
#
# -----------------------------------------------------------------
# Model Performance
# Testing Accuracy:  0.9034153507161219
# [[215   0  23   0   0   1  10]
#  [  0 107   1   0   0   1   0]
#  [ 12   0 260   0   6   1   0]
#  [  0   0   0 645   5   8  66]
#  [  2   0   8   4 360   0   8]
#  [  2   0   1  13   0 396  12]
#  [  3   0   4  58   5   9 477]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89       249
#            1       1.00      0.98      0.99       109
#            2       0.88      0.93      0.90       279
#            3       0.90      0.89      0.89       724
#            4       0.96      0.94      0.95       382
#            5       0.95      0.93      0.94       424
#            6       0.83      0.86      0.84       556
#
#     accuracy                           0.90      2723
#    macro avg       0.92      0.91      0.92      2723
# weighted avg       0.90      0.90      0.90      2723

# %%
from sklearn.model_selection import GridSearchCV
clf = DecisionTreeClassifier()

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %%
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 10, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy', verbose=1)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# Best Accuracy: 0.8982359613169318

# %%
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)
print("Test Accuracy:", test_score)
# Out:
# Test Accuracy: 0.9026808666911494

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg= LogisticRegression(max_iter= 1000)
param_grid= {
    'C': [0.001,0.01,0.1,1,10],
    'penalty': ['l1','l2','elasticnet'],
}

# %%
grid_search= GridSearchCV(log_reg,param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=1000),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10],
#                          'penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
grid_search.best_score_
# Out:
# 0.8511205511497824

# %%
from sklearn.linear_model import LogisticRegression

# %%
model= LogisticRegression(C= 1, penalty= 'l2')
model.fit(x_train, y_train)
y_train_predicted= model.predict(x_train)
y_test_predicted= model.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,precision_score,recall_score,confusion_matrix

# %%
print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,y_train_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,y_train_predicted))
print('Training classifiation_report:',classification_report(y_train,y_train_predicted))

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_predicted))
#print('Testing Precision:', precision_score(y_test,y_test_predicted))
#print('Testing Recall:',recall_score(y_test,y_test_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.7121601763409258
# Training Confusion Matrix:  [[ 408    0  451    0  152    1   61]
#  [   0  412    1    0    0    0    0]
#  [ 221    0 1043    0   81    0    6]
#  [   0    0    0 2394    0  350   78]
#  [  40    0   90   41 1084    0  291]
#  [   1    0    0  390    8  888  316]
#  [   0    0    0  121  143  291 1525]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       0.61      0.38      0.47      1073
#            1       1.00      1.00      1.00       413
#            2       0.66      0.77      0.71      1351
#            3       0.81      0.85      0.83      2822
#            4       0.74      0.70      0.72      1546
#            5       0.58      0.55      0.57      1603
#            6       0.67      0.73      0.70      2080
#
#     accuracy                           0.71     10888
#    macro avg       0.72      0.71      0.71     10888
# weighted avg       0.71      0.71      0.71     10888
#
# Model Performance
# Testing Accuracy: 0.7253029746603011
# Testing Confusion Matrix:  [[103   0  96   0  40   0  10]
#  [  0 108   1   0   0   0   0]
#  [ 58   0 211   0   9   0   1]
#  [  0   0   0 617   0  88  19]
#  [ 16   0  24   5 267   2  68]
#  [  0   0   0  96   5 260  63]
#  [  0   0   0  32  45  70 409]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.58      0.41      0.48       249
#            1       1.00      0.99      1.00       109
#            2       0.64      0.76      0.69       279
#            3       0.82      0.85      0.84       724
#            4       0.73      0.70      0.71       382
#            5       0.62      0.61      0.62       424
#            6       0.72      0.74      0.73       556
#
#     accuracy                           0.73      2723
#    macro avg       0.73      0.72      0.72      2723
# weighted avg       0.72      0.73      0.72      2723

# %% [markdown]
# KNN CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

knn = KNeighborsClassifier()

param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],  
    'weights': ['uniform', 'distance'],  
    'metric': ['euclidean', 'manhattan', 'minkowski'] 
}

grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train, y_train)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Accuracy: {grid_search.best_score_:.4f}")
# Out:
# Best Parameters: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
# Best Accuracy: 0.6083

# %%
knn_model= KNeighborsClassifier(metric= 'euclidean',n_neighbors= 11, weights= 'uniform')
knn_model.fit(x_train,y_train)
ytrain_knn_predicted= knn_model.predict(x_train)
ytrain_knn_predicted
# Out:
# array([3, 3, 0, ..., 5, 4, 6])

# %%
y_train
# Out:
# array([5, 3, 0, ..., 6, 4, 4])

# %%
print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,ytrain_knn_predicted))
#print('Training Precision:', precision_score(y_train,ytrain_knn_predicted))
#print('Training Recall:',recall_score(y_train,ytrain_knn_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,ytrain_knn_predicted))
print('Training classifiation_report:',classification_report(y_train,ytrain_knn_predicted))

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_predicted))
#print('Testing Precision:', precision_score(y_test,y_test_predicted))
#print('Testing Recall:',recall_score(y_test,y_test_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.6772593681116826
# Training Confusion Matrix:  [[ 384    0  454    0  197    1   37]
#  [   0  412    1    0    0    0    0]
#  [ 224    0 1035    0   89    1    2]
#  [   0    0    0 2465    0  261   96]
#  [  88    0   55   45  975   60  323]
#  [   0    0    1  459   63  655  425]
#  [   2    0    0  173  213  244 1448]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       0.55      0.36      0.43      1073
#            1       1.00      1.00      1.00       413
#            2       0.67      0.77      0.71      1351
#            3       0.78      0.87      0.83      2822
#            4       0.63      0.63      0.63      1546
#            5       0.54      0.41      0.46      1603
#            6       0.62      0.70      0.66      2080
#
#     accuracy                           0.68     10888
#    macro avg       0.69      0.68      0.68     10888
# weighted avg       0.67      0.68      0.67     10888
#
# Model Performance
# Testing Accuracy: 0.7253029746603011
# Testing Confusion Matrix:  [[103   0  96   0  40   0  10]
#  [  0 108   1   0   0   0   0]
#  [ 58   0 211   0   9   0   1]
#  [  0   0   0 617   0  88  19]
#  [ 16   0  24   5 267   2  68]
#  [  0   0   0  96   5 260  63]
#  [  0   0   0  32  45  70 409]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.58      0.41      0.48       249
#            1       1.00      0.99      1.00       109
#            2       0.64      0.76      0.69       279
#            3       0.82      0.85      0.84       724
#            4       0.73      0.70      0.71       382
#            5       0.62      0.61      0.62       424
#            6       0.72      0.74      0.73       556
#
#     accuracy                           0.73      2723
#    macro avg       0.73      0.72      0.72      2723
# weighted avg       0.72      0.73      0.72      2723

# %%
df.columns
# Out:
# Index(['Area', 'Extent', 'Solidity', 'ShapeFactor3', 'ShapeFactor4', 'Class'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(max_depth=10)

# %%
rf.fit (x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10)

# %%
ytrain_rf_predicted=rf.predict(x_train)
y_test_rf_predicted=rf.predict(x_test)

# %%
print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,ytrain_rf_predicted))
#print('Training Precision:', precision_score(y_train,ytrain_knn_predicted))
#print('Training Recall:',recall_score(y_train,ytrain_knn_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,ytrain_rf_predicted))
print('Training classifiation_report:',classification_report(y_train,ytrain_rf_predicted))

ytest_rf_predicted= rf.predict(x_test)

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,ytest_rf_predicted))
#print('Testing Precision:', precision_score(y_test,ytest_knn_predicted))
#print('Testing Recall:',recall_score(y_test,ytest_knn_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,ytest_rf_predicted))
print('Testing classifiation_report:',classification_report(y_test,ytest_rf_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.9495775165319618
# Training Confusion Matrix:  [[ 980    0   64    0    1    1   27]
#  [   0  413    0    0    0    0    0]
#  [  25    0 1313    0    4    2    7]
#  [   0    0    0 2687    0   12  123]
#  [   1    0   16    8 1495    0   26]
#  [   1    0    1   11    0 1550   40]
#  [   0    0    7  160    3    9 1901]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94      1073
#            1       1.00      1.00      1.00       413
#            2       0.94      0.97      0.95      1351
#            3       0.94      0.95      0.94      2822
#            4       0.99      0.97      0.98      1546
#            5       0.98      0.97      0.98      1603
#            6       0.90      0.91      0.90      2080
#
#     accuracy                           0.95     10888
#    macro avg       0.96      0.96      0.96     10888
# weighted avg       0.95      0.95      0.95     10888
#
# Model Performance
# Testing Accuracy: 0.919573999265516
# Testing Confusion Matrix:  [[219   0  18   0   1   1  10]
#  [  0 108   1   0   0   0   0]
#  [  9   0 264   0   4   1   1]
#  [  0   0   0 673   3   6  42]
#  [  1   0   7   3 363   0   8]
#  [  2   0   0   9   0 399  14]
#  [  0   0   2  62   8   6 478]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91       249
#            1       1.00      0.99      1.00       109
#            2       0.90      0.95      0.92       279
#            3       0.90      0.93      0.92       724
#            4       0.96      0.95      0.95       382
#            5       0.97      0.94      0.95       424
#            6       0.86      0.86      0.86       556
#
#     accuracy                           0.92      2723
#    macro avg       0.93      0.93      0.93      2723
# weighted avg       0.92      0.92      0.92      2723

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\saksh\anaconda3\lib\site-packages (5.16.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.115.8)
# Requirement already satisfied: ffmpy in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (1.7.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.9.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.45.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\saksh\anaconda3\lib\site-packages (from gradio-client==1.7.0->gradio) (2024.6.1)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\saksh\anaconda3\lib\site-packages (from gradio-client==1.7.0->gradio) (14.2)
# Requirement already satisfied: idna>=2.8 in c:\users\saksh\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\saksh\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\saksh\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\saksh\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\saksh\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\saksh\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\saksh\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\saksh\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saksh\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saksh\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saksh\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\saksh\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\saksh\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\saksh\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\saksh\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\saksh\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\saksh\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\saksh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\saksh\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\saksh\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saksh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saksh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\saksh\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
import gradio as gr
def prediction(Area, Extent, Solidity, ShapeFactor3, ShapeFactor4):
    input_data= np.array([[Area, Extent,Solidity,ShapeFactor3,ShapeFactor4]])
    input_data.reshape(1,-1)
    prediction= rf.predict(input_data)
    return le.inverse_transform(prediction)[0]

# %%
y_train
# Out:
# array([5, 3, 0, ..., 6, 4, 4])

# %%
prediction(3.53640000e+04,7.92168810e-01,9.88898521e-01,9.111973933e-01,9.98391922e-01)
# Out:
# 'SEKER'

# %%
inputs= [
    gr.Number(label= 'Enter Area'),
    gr.Number(label= 'Enter Extent'),
    gr.Number(label= 'Enter  Solidity'),
    gr.Number(label= 'Enter ShapeFactor3'),
    gr.Number(label= 'Enter ShapeFactor4')
]

# %%
output= gr.Textbox(label= 'Prediction')

# %%
gr.Interface(fn= prediction,inputs= inputs,outputs= output,
            title = "Beans classification",
    description = "Enter the input data ",
    ).launch(share = True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://22b0cccf4d2ac20141.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://22b0cccf4d2ac20141.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from sklearn.svm import SVC

svc= SVC(C=1.0,kernel= 'linear')
svc.fit(x_train,y_train)
y_train_svm_predicted= svc.predict(x_train)
y_test_svm_predicted= svc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score ,confusion_matrix

print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,y_train_svm_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,y_train_svm_predicted))
print('Training classifiation_report:',classification_report(y_train,y_train_svm_predicted))

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_svm_predicted))
#print('Testing Precision:', precision_score(y_test,y_test_predicted))
#print('Testing Recall:',recall_score(y_test,y_test_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_svm_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_svm_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.6272042615723733
# Training Confusion Matrix:  [[ 145    0  677    0  226    0   25]
#  [   0  412    1    0    0    0    0]
#  [  96    0 1160    0   92    0    3]
#  [   0    0    0 2413    0  342   67]
#  [  99    0   60   34  995   54  304]
#  [   0    0    0  576   80  454  493]
#  [   1    0    0  118  390  321 1250]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       0.43      0.14      0.21      1073
#            1       1.00      1.00      1.00       413
#            2       0.61      0.86      0.71      1351
#            3       0.77      0.86      0.81      2822
#            4       0.56      0.64      0.60      1546
#            5       0.39      0.28      0.33      1603
#            6       0.58      0.60      0.59      2080
#
#     accuracy                           0.63     10888
#    macro avg       0.62      0.62      0.61     10888
# weighted avg       0.60      0.63      0.60     10888
#
# Model Performance
# Testing Accuracy: 0.6312890194638267
# Testing Confusion Matrix:  [[ 33   0 155   0  59   0   2]
#  [  0 108   1   0   0   0   0]
#  [ 31   0 236   0  12   0   0]
#  [  0   0   0 618   0  87  19]
#  [ 30   0  17   3 250   9  73]
#  [  0   0   0 141  17 139 127]
#  [  0   0   0  33 106  82 335]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.35      0.13      0.19       249
#            1       1.00      0.99      1.00       109
#            2       0.58      0.85      0.69       279
#            3       0.78      0.85      0.81       724
#            4       0.56      0.65      0.61       382
#            5       0.44      0.33      0.38       424
#            6       0.60      0.60      0.60       556
#
#     accuracy                           0.63      2723
#    macro avg       0.62      0.63      0.61      2723
# weighted avg       0.61      0.63      0.61      2723

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
model1= LogisticRegression()
model2= DecisionTreeClassifier()
model3= SVC()

ensemble_classifier= VotingClassifier(
    estimators=[('lr',model1),('dt',model2),('svc',model3)],voting='hard')

ensemble_classifier.fit(x_train,y_train)
y_train_predicted= ensemble_classifier.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score ,confusion_matrix

print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,y_train_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,y_train_predicted))
print('Training classifiation_report:',classification_report(y_train,y_train_predicted))

y_test_predicted= ensemble_classifier.predict(x_test)

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_predicted))
#print('Testing Precision:', precision_score(y_train,y_train_predicted))
#print('Testing Recall:',recall_score(y_train,y_train_predicted)) 
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.7480712711241734
# Training Confusion Matrix:  [[ 433    0  451    0  152    0   37]
#  [   0  412    1    0    0    0    0]
#  [  71    0 1194    0   81    0    5]
#  [   0    0    0 2470    0  289   63]
#  [  39    0   73   42 1139    0  253]
#  [   1    0    0  390   38  888  286]
#  [   0    0    0  129  126  216 1609]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       0.80      0.40      0.54      1073
#            1       1.00      1.00      1.00       413
#            2       0.69      0.88      0.78      1351
#            3       0.81      0.88      0.84      2822
#            4       0.74      0.74      0.74      1546
#            5       0.64      0.55      0.59      1603
#            6       0.71      0.77      0.74      2080
#
#     accuracy                           0.75     10888
#    macro avg       0.77      0.75      0.75     10888
# weighted avg       0.75      0.75      0.74     10888
#
# Model Performance
# Testing Accuracy: 0.7477047374219611
# Testing Confusion Matrix:  [[100   0 100   0  40   0   9]
#  [  0 108   1   0   0   0   0]
#  [ 24   0 245   0  10   0   0]
#  [  0   0   0 625   0  78  21]
#  [ 11   0  21   6 281   1  62]
#  [  0   0   0  97   9 255  63]
#  [  0   0   0  39  43  52 422]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.74      0.40      0.52       249
#            1       1.00      0.99      1.00       109
#            2       0.67      0.88      0.76       279
#            3       0.81      0.86      0.84       724
#            4       0.73      0.74      0.73       382
#            5       0.66      0.60      0.63       424
#            6       0.73      0.76      0.74       556
#
#     accuracy                           0.75      2723
#    macro avg       0.76      0.75      0.75      2723
# weighted avg       0.75      0.75      0.74      2723

# %%
from sklearn.ensemble import AdaBoostClassifier
model3= RandomForestClassifier()

# %%
ensemble_classifier= VotingClassifier(
    estimators=[('lr',model1),('dt',model2),('rf',model3)],voting='soft')

# %%
adaboost= AdaBoostClassifier(
    estimator= ensemble_classifier,
    learning_rate=1.0,
    random_state= 40
)

# %%
adaboost.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(estimator=VotingClassifier(estimators=[('lr',
#                                                            LogisticRegression()),
#                                                           ('dt',
#                                                            DecisionTreeClassifier()),
#                                                           ('rf',
#                                                            RandomForestClassifier())],
#                                               voting='soft'),
#                    random_state=40)

# %%
y_train_predicted=adaboost.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score ,confusion_matrix

print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,y_train_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,y_train_predicted))
print('Training classifiation_report:',classification_report(y_train,y_train_predicted))

y_test_predicted= adaboost.predict(x_test)

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_predicted))
#print('Testing Precision:', precision_score(y_train,y_train_predicted))
#print('Testing Recall:',recall_score(y_train,y_train_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy: 1.0
# Training Confusion Matrix:  [[1073    0    0    0    0    0    0]
#  [   0  413    0    0    0    0    0]
#  [   0    0 1351    0    0    0    0]
#  [   0    0    0 2822    0    0    0]
#  [   0    0    0    0 1546    0    0]
#  [   0    0    0    0    0 1603    0]
#  [   0    0    0    0    0    0 2080]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1073
#            1       1.00      1.00      1.00       413
#            2       1.00      1.00      1.00      1351
#            3       1.00      1.00      1.00      2822
#            4       1.00      1.00      1.00      1546
#            5       1.00      1.00      1.00      1603
#            6       1.00      1.00      1.00      2080
#
#     accuracy                           1.00     10888
#    macro avg       1.00      1.00      1.00     10888
# weighted avg       1.00      1.00      1.00     10888
#
# Model Performance
# Testing Accuracy: 0.8990084465662872
# Testing Confusion Matrix:  [[215   0  25   0   1   1   7]
#  [  0 108   0   0   0   1   0]
#  [ 19   0 249   0   9   1   1]
#  [  0   0   0 663   2   7  52]
#  [  4   0   3   4 360   0  11]
#  [  4   0   1  13   0 388  18]
#  [  6   0   1  58   6  20 465]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       249
#            1       1.00      0.99      1.00       109
#            2       0.89      0.89      0.89       279
#            3       0.90      0.92      0.91       724
#            4       0.95      0.94      0.95       382
#            5       0.93      0.92      0.92       424
#            6       0.84      0.84      0.84       556
#
#     accuracy                           0.90      2723
#    macro avg       0.91      0.91      0.91      2723
# weighted avg       0.90      0.90      0.90      2723

# %%
from xgboost import XGBClassifier

xgb= XGBClassifier()
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\saksh\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\saksh\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\saksh\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
y_train_predicted= xgb.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score ,confusion_matrix

print('Model Performance')
print('Training Accuracy:', accuracy_score(y_train,y_train_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Training Confusion Matrix: ', confusion_matrix(y_train,y_train_predicted))
print('Training classifiation_report:',classification_report(y_train,y_train_predicted))

y_test_predicted= xgb.predict(x_test)

print('Model Performance')
print('Testing Accuracy:', accuracy_score(y_test,y_test_predicted))
#print('Training Precision:', precision_score(y_train,y_train_predicted))
#print('Training Recall:',recall_score(y_train,y_train_predicted))
print('Testing Confusion Matrix: ', confusion_matrix(y_test,y_test_predicted))
print('Testing classifiation_report:',classification_report(y_test,y_test_predicted))
# Out:
# Model Performance
# Training Accuracy: 0.99834680382072
# Training Confusion Matrix:  [[1073    0    0    0    0    0    0]
#  [   0  413    0    0    0    0    0]
#  [   0    0 1351    0    0    0    0]
#  [   0    0    0 2818    0    0    4]
#  [   0    0    0    0 1546    0    0]
#  [   0    0    0    0    0 1603    0]
#  [   0    0    0   14    0    0 2066]]
# Training classifiation_report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1073
#            1       1.00      1.00      1.00       413
#            2       1.00      1.00      1.00      1351
#            3       1.00      1.00      1.00      2822
#            4       1.00      1.00      1.00      1546
#            5       1.00      1.00      1.00      1603
#            6       1.00      0.99      1.00      2080
#
#     accuracy                           1.00     10888
#    macro avg       1.00      1.00      1.00     10888
# weighted avg       1.00      1.00      1.00     10888
#
# Model Performance
# Testing Accuracy: 0.9151670951156813
# Testing Confusion Matrix:  [[226   1  15   0   0   0   7]
#  [  0 109   0   0   0   0   0]
#  [  8   0 264   0   5   1   1]
#  [  0   0   0 664   3   7  50]
#  [  1   0   6   1 364   0  10]
#  [  4   0   0  13   0 396  11]
#  [  2   0   1  70   8   6 469]]
# Testing classifiation_report:               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92       249
#            1       0.99      1.00      1.00       109
#            2       0.92      0.95      0.93       279
#            3       0.89      0.92      0.90       724
#            4       0.96      0.95      0.96       382
#            5       0.97      0.93      0.95       424
#            6       0.86      0.84      0.85       556
#
#     accuracy                           0.92      2723
#    macro avg       0.93      0.93      0.93      2723
# weighted avg       0.92      0.92      0.92      2723
